# %% [markdown]
# <a href="https://colab.research.google.com/github/JYKnomad/JYKnomad/blob/main/20220228.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pynrrd
# !pip install pynrrd
#!pip install numpy-stl

import numpy as np
import nrrd
import os
from stl import mesh

# %%
readdata, header = nrrd.read('/content/sample_data/0228.nrrd')

# %%
print(readdata.shape)
# Out:
# (512, 512, 307)

# %%
print(header)
# Out:
# OrderedDict([('type', 'unsigned char'), ('dimension', 3), ('space', 'left-posterior-superior'), ('sizes', array([512, 512, 307])), ('space directions', array([[0.9765625, 0.       , 0.       ],
#        [0.       , 0.9765625, 0.       ],
# ...

# %%
readdata[:,:,30]
# Out:
# array([[2, 2, 2, ..., 2, 2, 2],
#        [2, 2, 2, ..., 2, 2, 2],
#        [2, 2, 2, ..., 2, 2, 2],
#        ...,
#        [2, 2, 2, ..., 2, 2, 2],
#        [2, 2, 2, ..., 2, 2, 2],
#        [2, 2, 2, ..., 2, 2, 2]], dtype=uint8)

# %%
np.unique(readdata[:,:,30])
# Out:
# array([1, 2], dtype=uint8)

# %%
path="/content/sample_data"

 

os.chdir(path)

ctl = mesh.Mesh.from_file('Segmentation_Body.stl')

# %%
ctl

# %%
np.shape(ctl)
# Out:
# (1347952, 9)
